# %%
a= 2
Name= "Avic"
Price="10.9"
is_paid=True

print(type(a))
print(type(Name))
print(type(Price))
print(type(is_paid))

# %%
x=(1,"date",False,2.2)
x.append(2)
x

# %% [markdown]
# # Create a record for an order:
# # fields: order_id, customer_name, items (list), total_amount
#
# # Print:
# # - type of each field
# # - total number of items

# %%
field={"order_id":"22","customer_name":"Avic","item_list":"45"}
field

# %%
print(type(field))
print

# %% [markdown]
# # Given:
# data = [100, 200, 50, 400]
#
# # Calculate:
# # - total revenue
# # - count of transactions > 150
